# %%
def train(classifier, X, y):
    start = time.time()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

    

    classifier.fit(X_train, y_train) 
                                                           
    end = time.time()

    y_pred = classifier.predict(X_test) 

    df_description(classifier, y_test, y_pred, y_train, X_train, X_test, y_train)
   
    c_report = metrics.classification_report(y_test, y_pred, output_dict=True) 
    report_chart(c_report)
    print('\n\n', metrics.classification_report(y_test, y_pred))
    print('\n\n', c_report)
  
  
    # create a dataframe with X_test and y_test columns
    test_df = pd.concat([X_test, y_test], axis=1)

    # add predicted values to the dataframe
    test_df['PREDICTIONS'] = y_pred
    
   
    return test_df

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a pandas dataframe
df = pd.read_csv('data.csv')

# Count the number of occurrences of each category in the column
counts = df['column_name'].value_counts()

# Calculate the percentage of each category
percentages = (counts / len(df)) * 100

# Create the bar plot
fig, ax = plt.subplots()
ax.bar(counts.index, counts.values, color='b')
ax.set_ylabel('Number of occurrences')
ax2 = ax.twinx()
ax2.plot(counts.index, percentages.values, color='r', marker='o', ms=5)
ax2.yaxis.set_major_formatter('{x:.0f}%')
ax2.set_ylabel('Percentage')
ax.set_xticklabels(counts.index, rotation=90)
ax.set_xticks(counts.index)
plt.show()

# %%
import numpy as np
import pandas as pd
# For visualizations
import matplotlib.pyplot as plt
# For regular expressions
import re
# For handling string
import string
# For performing mathematical operations
import math

import swifter
import spacy
import ssl
from spacy import displacy
import pandas as pd
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from sklearn.metrics import accuracy_score
from spacy.matcher import Matcher
from spacy.pipeline import EntityRuler

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzywuzzy import process, fuzz

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
stop=set(stopwords.words('english'))
#nltk.download('stopwords')

from sklearn.linear_model import LogisticRegression

from joblib import Parallel, delayed

from tqdm import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt

import seaborn as sns

import re

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing

from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split

global cls_acc
cls_acc = 0
global cls_time
cls_time = 0
import time
import io

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from IPython.display import display
from IPython.display import display

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

import seaborn as sns
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202304131455.csv')
#reporting_ncr_all_transactions_202303081506
#df2 = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202303081506.csv')
# Out:
# C:\Users\Olimpio.Dasilva\AppData\Local\Temp\ipykernel_15868\899217176.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202304131455.csv')

# %%
df.shape
# Out:
# (2000000, 16)

# %%
df = df[df["merchant_name"].str.contains("Unknow Merchant") == False]

# %%
df.shape
# Out:
# (975608, 16)

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

plt.bar(top_categories.index, top_categories.values, align='center')

ax2 = plt.twinx()
ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')



plt.xlabel('Category')
plt.ylabel('Number of Occurrences')
plt.title('Top 10 Categories by Occurrence')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

plt.bar(top_categories.index, top_categories.values, align='center')

ax2 = plt.twinx()
ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences')
plt.title('Top 10 Categories by Occurrence')

plt.xticks(rotation=45) # add this line to rotate categories vertically

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

plt.bar(top_categories.index, top_categories.values, align='center')

ax2 = plt.twinx()
ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences')
plt.title('Top 10 Categories by Occurrence')

plt.xticks(rotation=90) # Rotate the x-axis labels by 90 degrees

plt.show()

# %%
import matplotlib
#matplotlib.use('TkAgg')
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

plt.bar(top_categories.index, top_categories.values, align='center')

ax2 = plt.twinx()
ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences')
plt.title('Top 10 Categories by Occurrence')

#plt.xticks(rotation=90) # Rotate the x-axis labels by 90 degrees

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.use('TkAgg')

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

plt.xticks(rotation=90)
plt.bar(top_categories.index, top_categories.values, align='center', color=colors)

ax2 = plt.twinx()
ax2.set_ylim([0, 100])
ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences (%)')
plt.title('Top 10 Categories by Occurrence (Known Merchants)')

plt.show()

# %%
ax2.set_ylim([0, max_percentage + 10])
ax2.plot(category_percentages.index, category_percentages.values, color='red', linewidth=2.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.use('TkAgg')

max_percentage = category_percentages.max()

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

plt.xticks(rotation=90)
plt.bar(top_categories.index, top_categories.values, align='center', color=colors)

ax2 = plt.twinx()
#ax2.set_ylim([0, 100])
ax2.plot(category_percentages.index, category_percentages.values, color='red', linewidth=2.5)
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences (%)')
plt.title('Top 10 Merchant Names')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data and calculate category frequencies
#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

# Create bar plot
fig, ax = plt.subplots()
ax.bar(top_categories.index, top_categories.values, align='center', color=colors)

# Scale the red line and plot it
scaling_factor = ax.get_ylim()[1] / 100
ax2 = ax.twinx()
ax2.plot(category_percentages.index, category_percentages.values * scaling_factor, color='red')
ax2.set_ylim([0, 100])
ax2.set_ylabel('Percentage')
ax.set_ylim([0, 975608])

# Set axis labels, title and display plot
ax.set_xticklabels(top_categories.index, rotation=90)
ax.set_xlabel('Category')
ax.set_ylabel('Number of Occurrences')
ax.set_title('Top 10 Categories by Occurrence (Known Merchants)')
plt.show()
# Out:
# C:\Users\Olimpio.Dasilva\AppData\Local\Temp\ipykernel_15868\3535083579.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(top_categories.index, rotation=90)

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

fig, ax1 = plt.subplots()

ax1.bar(top_categories.index, top_categories.values, align='center', color=colors)
ax1.set_xlabel('Category')
ax1.set_ylabel('Number of Occurrences')
ax1.tick_params(axis='y')

ax2 = ax1.twinx()
#ax2.plot(category_percentages.index, category_percentages.values, color='red')
ax2.set_ylabel('Percentage')
ax2.set_ylim([0, 100])

# Set the y-axis limits to display from 0 to 1000000
ax1.set_ylim([0, 975608])

plt.xticks(rotation=45)
plt.title('Top 10 Categories by Occurrence (Known Merchants)')

plt.show()

# %%
df.shape
# Out:
# (975608, 16)

# %%
df2 = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202303081506.csv')

# %%
df2.shape
