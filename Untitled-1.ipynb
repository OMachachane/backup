# %%
import numpy as np
import pandas as pd
# For visualizations
import matplotlib.pyplot as plt
# For regular expressions
import re
# For handling string
import string
# For performing mathematical operations
import math

import swifter
import spacy
import ssl
from spacy import displacy
import pandas as pd
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from sklearn.metrics import accuracy_score
from spacy.matcher import Matcher
from spacy.pipeline import EntityRuler

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzywuzzy import process, fuzz

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
stop=set(stopwords.words('english'))
#nltk.download('stopwords')

from sklearn.linear_model import LogisticRegression

from joblib import Parallel, delayed

from tqdm import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt

import seaborn as sns

import re

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing

from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split

global cls_acc
cls_acc = 0
global cls_time
cls_time = 0
import time
import io

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from IPython.display import display
from IPython.display import display

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

import seaborn as sns
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA - Exploratory Data Anaysis
# - Importing the original dataset
# - Checking the number of rows and columns of the dataset
# - Checking the total of null values per columns
# - Checking the total of unique values per column

# %%
#df = pd.read_parquet('C:/Users/Olimpio.Dasilva/Desktop/MACHINE LEARNING/DATA/reporting_ncr_all_transactions_202302131044.parquet')
df = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202303081506.csv')
#df = pd.read_csv('C:/Users/Olimpio.Dasilva/Desktop/random_sampling/reporting_ncr_all_transactions_202303081406.csv')
pd.set_option('display.max_colwidth', None)
df = df.sample(10000)
df.head(5)
# Out:
#           fi_id                         account_id  \
# 793570   DI1460  Af5e4f8c20087324b97000e228919a808
# 102727   DI1041  A4d77a7b7d2ec31eba47eecfd75f716b7
# 1474089  DI1041  A7790496333ee34309d8e0dc7841c5ff9
# 164115   DI4385  A4dd03c928a6431d1a93626bd65cded1a
# 1139311  DI1711  A4308cf5d51873dfb87d129ae40ca7671
#
#                             transaction_id  amount currency  \
# 793570   T59f1843392b63c0d810fa14b4db6d7b2   18.12      USD
# 102727   Te7284534069a3632a6e511010d7f65b7    5.26      USD
# 1474089  T246c3f9fe70939e3bdb2e4569945c45d    3.41      USD
# 164115   Tb9b7ad9ee99f3fe0b3ac797c09c902b7    6.65      USD
# 1139311  T68ed35bd507f31a89822f5a88dcb3db9   32.36      USD
#
#                                                                 txn_desc1  \
# 793570                                           Point Of Sale Withdrawal
# 102727                                                     Withdrawal POS
# 1474089                                             Withdrawal Debit Card
# 164115                                    Point Of Sale Withdrawal Pinned
# 1139311  DBT CRD 1456 05/10/22 *9 FOOD LION #0871 SHEPHERDSTOWN WV C#8557
#
#                                                  txn_desc2 region  \
# 793570         AMAZON.COM*JB5A82DG3 AMAZON.COM SEATTLE WAU    NaN
# 102727                      DOLLAR-GENERAL # DG *70 PENN L    NaN
# 1474089       Withdrawal WALMART.COM *6546 800-966-6546 AR     AR
# 164115   THE HOME DEPOT 139 COMMERCIAL ROADLEOMINSTER MAUS    NaN
# 1139311                                                NaN    NaN
#
#         transaction_timestamp  merchant_id   merchant_name  \
# 793570             2022-12-01      10127.0      AMAZON.COM
# 102727             2022-05-27      10880.0  DOLLAR GENERAL
# 1474089            2022-11-28      13085.0         WALMART
# 164115             2022-09-27      11419.0      HOME DEPOT
# 1139311            2022-05-11      11111.0       FOOD LION
#
#                 payment_agent payment_agent_id extract_date  \
# 793570   Unknow Payment Agent              NaN   2022-12-04
# 102727   Unknow Payment Agent              NaN   2022-11-03
# 1474089  Unknow Payment Agent              NaN   2022-11-30
# 164115   Unknow Payment Agent              NaN   2022-09-29
# 1139311  Unknow Payment Agent              NaN   2022-05-14
#
#                                      filename                            name
# 793570   FTS_CSLK_TRANSAC_20221203_100006.csv         Evansville Teachers Fcu
# 102727   FTS_CSLK_TRANSAC_20221102_100007.csv  CLEARVIEW FEDERAL CREDIT UNION
# 1474089  FTS_CSLK_TRANSAC_20221129_100007.csv  CLEARVIEW FEDERAL CREDIT UNION
# 164115   FTS_CSLK_TRANSAC_20220928_100033.csv            Clinton Savings Bank
# 1139311  FTS_CSLK_TRANSAC_20220513_100001.csv            Bank of Charles Town

# %%
print('Total number of rows and columns:', df.shape)
# Out:
# Total number of rows and columns: (10000, 16)

# %%
print('Total number of null values per column:')
df.isnull().sum()
# Out:
# Total number of null values per column:
# fi_id                       0
# account_id                  0
# transaction_id              0
# amount                      0
# currency                    0
# txn_desc1                   1
# txn_desc2                 842
# region                   8408
# transaction_timestamp       0
# merchant_id                 0
# merchant_name               0
# payment_agent               0
# payment_agent_id         9503
# extract_date                0
# filename                    0
# name                        0
# dtype: int64

# %%
print('Total number of unique values per column:')
df.nunique()
# Out:
# Total number of unique values per column:
# fi_id                      156
# account_id                9186
# transaction_id           10000
# amount                    5309
# currency                     1
# txn_desc1                 3633
# txn_desc2                 8325
# region                      42
# transaction_timestamp      494
# merchant_id                676
# merchant_name              677
# payment_agent               14
# payment_agent_id            19
# extract_date               460
# filename                   499
# name                       156
# dtype: int64

# %%
df_unknown_merchs = df.copy(deep=True)
df_unknown_merchs = df_unknown_merchs[df["merchant_name"].str.contains("Unknow Merchant") == True]
print('Total number of rows and columns:', df_unknown_merchs.shape)
# Out:
# Total number of rows and columns: (0, 16)

# %% [markdown]
# # Known Merchant Names
# - Selecting known merchants only
# - Checking the number of rows/transactions
# - Checking the total number of merchants
# - Checking the total number of occurrences per merchant
# - Concatenated the transaction details columns
# - Defined a function for word cloud for top merchants
# - Defined a function for N-gram for top merchants with combined names
# - Defined a function to check occurence of merchants in transaction columns

# %%
# Selecting only known merchants names from the original dataset
df_known_merchs = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
df_known_merchs = df_known_merchs[df["merchant_name"].str.contains("Unknow Merchant") == False]

df_known_merchs_cp2 = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
df_known_merchs_cp2 = df_known_merchs_cp2[df["merchant_name"].str.contains("Unknow Merchant") == False]

# %%
# # Selecting only known merchants names from the original dataset
# df_known_merchs = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
# df_known_merchs = df_known_merchs[df["merchant_name"].str.contains("Unknow Merchant") == False]

# df_known_merchs_cp2 = df[['transaction_id','txn_desc1','txn_desc2','payment_agent','merchant_name']].copy(deep=True)
# df_known_merchs_cp2 = df_known_merchs_cp2[df["merchant_name"].str.contains("Unknow Merchant") == False]

# #df_known_merchs = df_known_merchs.head(50)

# %%
print('Number of transactions with known merchant names:\n',len(df_known_merchs))
# Out:
# Number of transactions with known merchant names:
#  10000

# %%
print('Total number of known merchants:\n',len(df_known_merchs.merchant_name.unique()))
# Out:
# Total number of known merchants:
#  677

# %%
merch_dist = (df_known_merchs.merchant_name).value_counts(normalize=True).mul(100).round(1).astype(str)
print('Total number of occurences per merchant name:\n', merch_dist + '%')
# Out:
# Total number of occurences per merchant name:
#  AMAZON.COM                8.6%
# WALMART                   6.8%
# MCDONALD'S                3.3%
# APPLE STORE               2.8%
# TARGET                    2.4%
#                           ...
# UGG                       0.0%
# CAPTAIN D'S               0.0%
# COST PLUS WORLD MARKET    0.0%
# SHERATON                  0.0%
# BOOKS-A-MILLION           0.0%
# Name: merchant_name, Length: 677, dtype: object

# %%
# Concatenating transaction descriptions columns
df_known_merchs["TRANSACTION_DETAILS"] = df_known_merchs['txn_desc1'].astype(str) +" %%%%% "+ df_known_merchs['txn_desc2'].astype(str)
df_known_merchs.sample(5)
# Out:
#                             transaction_id                   txn_desc1  \
# 394460   T46fedb5cc1fb3837bf5967bf1763bc69                  Debit Card
# 1394567  Tb2c6a646825c36f5b30a04c51b4c19ce  Withdrawal Debit AMZN Mktp
# 418621   Tc39948ba463f398cbb791e70a28abab5       Withdrawal DEBIT CARD
# 1273853  T8e295e119d6338b18ba8e5da236e42d0            DEBIT CARD DEBIT
# 1237423  T1fe4f9ed9ef2389981b2e6aaf7f23055                  WITHDRAWAL
#
#                                                                                                    txn_desc2  \
# 394460                                           SHELLEY ACE HARDWARE SHELLEY ID Date 01/27/23 ***36070 5251
# 1394567                                                                       US*1U17F8FP1 Amzn.com/billWAUS
# 418621   AFTERPAY 760 Market Street, Floo SAN FRANC Date 12/11/22 1 *917 6 5999 %% Card 15 #4856 %% MCC 5999
# 1273853                                                            auth #* 03-30-2022 COMCAST 800-COMCAST MD
# 1237423                                                            POS 1224 0945 * TARGET T-2432 Dayville CT
#
#                 payment_agent  merchant_name  \
# 394460   Unknow Payment Agent   ACE HARDWARE
# 1394567  Unknow Payment Agent     AMAZON.COM
# 418621   Unknow Payment Agent  MARKET STREET
# 1273853  Unknow Payment Agent        COMCAST
# 1237423  Unknow Payment Agent         TARGET
#
#                                                                                                                      TRANSACTION_DETAILS
# 394460                                                      Debit Card %%%%% SHELLEY ACE HARDWARE SHELLEY ID Date 01/27/23 ***36070 5251
# 1394567                                                                  Withdrawal Debit AMZN Mktp %%%%% US*1U17F8FP1 Amzn.com/billWAUS
# 418621   Withdrawal DEBIT CARD %%%%% AFTERPAY 760 Market Street, Floo SAN FRANC Date 12/11/22 1 *917 6 5999 %% Card 15 #4856 %% MCC 5999
# 1273853                                                                 DEBIT CARD DEBIT %%%%% auth #* 03-30-2022 COMCAST 800-COMCAST MD
# 1237423                                                                       WITHDRAWAL %%%%% POS 1224 0945 * TARGET T-2432 Dayville CT

# %%
def word_cloud(a):
    # Word cloud for more frequent merchant names
    text = " ".join(i for i in a)
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
    plt.figure( figsize=(7,7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
# Copy of the afs merchant names column
df_known_merchs['AFS_PAYMENT_AGENTS'] = df_known_merchs['payment_agent'] 
# Copy of the afs merchant names column
df_known_merchs['AFS_MECHANT_NAMES'] = df_known_merchs['merchant_name']
# Droping original cols
df_known_merchs = df_known_merchs.drop(['txn_desc1', 'txn_desc2','payment_agent','merchant_name'], axis=1)

# Word cloud for more frequent merchant names
word_cloud(df_known_merchs.AFS_MECHANT_NAMES)

# %%
#df = pd.read_csv('data.csv')
top_categories = df['merchant_name'].value_counts().nlargest(10)
category_percentages = top_categories / len(df) * 100

# Define a custom color palette
colors = ['#003865', '#FF9230', '#00A9AB']

plt.xticks(rotation=90)
plt.bar(top_categories.index, top_categories.values, align='center', color=colors)

ax2 = plt.twinx()
#ax2.set_ylim([0, 100])
ax2.plot(category_percentages.index, category_percentages.values, color='red', linewidth=2.5)
ax2.set_ylabel('Percentage')

plt.xlabel('Category')
plt.ylabel('Number of Occurrences (%)')
plt.title('Top 10 Merchant Names')

plt.show()

# %%
df_known_merchs
# Out:
#                             transaction_id  \
# 793570   T59f1843392b63c0d810fa14b4db6d7b2
# 102727   Te7284534069a3632a6e511010d7f65b7
# 1474089  T246c3f9fe70939e3bdb2e4569945c45d
# 164115   Tb9b7ad9ee99f3fe0b3ac797c09c902b7
# 1139311  T68ed35bd507f31a89822f5a88dcb3db9
# ...                                    ...
# 99012    T86acf1ad486036338734aec2dce581c5
# 928097   T4ca71336d0b5367199b2a3a3b252405d
# 1017229  Tce9278c0033334f69573074df494d45e
# 1031068  Tadf9f12557f53a10b285e1c8f8d563a5
# 701927   Td2c5390027903b27bfc39b1b5a5b55f7
#
#                                                                              TRANSACTION_DETAILS  \
# 793570                Point Of Sale Withdrawal %%%%% AMAZON.COM*JB5A82DG3 AMAZON.COM SEATTLE WAU
# 102727                                       Withdrawal POS %%%%% DOLLAR-GENERAL # DG *70 PENN L
# 1474089                 Withdrawal Debit Card %%%%% Withdrawal WALMART.COM *6546 800-966-6546 AR
# 164115   Point Of Sale Withdrawal Pinned %%%%% THE HOME DEPOT 139 COMMERCIAL ROADLEOMINSTER MAUS
# 1139311               DBT CRD 1456 05/10/22 *9 FOOD LION #0871 SHEPHERDSTOWN WV C#8557 %%%%% nan
# ...                                                                                          ...
# 99012                                                   POS MCDONALD'S F1074 ROSEDALE %%%%% NYUS
# 928097                                                Withdrawal #** %%%%% H-E-B #492 HOUSTON TX
# 1017229        Card purchase %%%%% APPLE CASH - SENT MONE 4829 (2022-11-23) 877-233-8552 CA 1093
# 1031068                                    PAYPAL *WALMART San Jose %%%%% CAUS : POS Transaction
# 701927                                            POS Withdrawal LOWE'S #2824 %%%%% SCHERTZ TXUS
#
#            AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES
# 793570   Unknow Payment Agent        AMAZON.COM
# 102727   Unknow Payment Agent    DOLLAR GENERAL
# 1474089  Unknow Payment Agent           WALMART
# 164115   Unknow Payment Agent        HOME DEPOT
# 1139311  Unknow Payment Agent         FOOD LION
# ...                       ...               ...
# 99012    Unknow Payment Agent        MCDONALD'S
# 928097   Unknow Payment Agent       HEB GROCERY
# 1017229            APPLE CASH       APPLE STORE
# 1031068                PAYPAL           WALMART
# 701927   Unknow Payment Agent            LOWE'S
#
# [10000 rows x 4 columns]

# %%
def get_top_ngram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:10]

# %%
top_n_bigrams=get_top_ngram(df_known_merchs['AFS_MECHANT_NAMES'],2)[:10] 
x,y=map(list,zip(*top_n_bigrams)) 
sns.barplot(x=y,y=x);

# %%
def check_names(merchant, t_details):
    
    # Variations for merchant name column
    merchant_1 = merchant
    merchant_2 = merchant_1.lower()
    merchant_3 = re.sub("[\\\\/:*?'#<>|-]", '', merchant_2)
    merchant_4 = re.sub(' ', '', merchant_2)
    merchant_5 = re.sub('[.com/%]', ' ', merchant_2)
    merch_list = merchant_1.split() + merchant_2.split() + merchant_3.split() + merchant_4.split() + merchant_5.split() + merchant.split()
    
    # Variations for transaction details column
    t_details_1 = t_details
    t_details_2 = t_details.lower()
    t_details_3 = re.sub("[\\\\/:*?'#<>|-]", '', t_details_2)
    t_details_4 = re.sub("[.com/%]", " ",t_details_2)
    t_details_5 = re.sub("[\\\\/:*?'#<>|-]", ' ', t_details_2)
    date_pattern = re.sub("\d{1,2}/\d{1,2}(/\d{2,4})?", "", t_details_2)
    
    # Merchants mentioned in transaction description w/ variations
    comp_1 = re.sub("Prime", "AMAZONVOD",t_details_1)
    comp_2 = re.sub("VZWRLSS", "VERIZON WIRELESS",t_details_1)
    comp_3 = re.sub("WM", "WALMART",t_details_1)
    
    # Creating a list of conversions to check if merchants are mentioned in transation descriotions 
    details_lis = t_details_2.split()
    details_lis_1 = t_details_1.split() + t_details_2.split() + t_details_3.split() + details_lis + t_details_4.split() + t_details_5.split() + comp_1.split() + comp_2.split() + comp_3.split() + t_details.split() + date_pattern.split()
    
    # Conditions to check if words are in transaction strings
    if (merchant in t_details_3 or t_details_3 in merchant or           
        (merchant_2 in t_details_3 or t_details_3 in merchant_2) or 
        (merchant_3 in t_details_3 or t_details_3 in merchant_3) or
        (merchant_4 in t_details_3 or t_details_3 in merchant_4) or
        (merchant_1 in t_details_3 or t_details_1 in merchant_4) or
        (merchant_1 in details_lis_1 or merchant_4 in details_lis)or
        (any(item in merch_list for item in details_lis_1)) or
        (merchant_1[:4] in t_details_1)):
        return True
    else:
        return False

# %% [markdown]
# - Checked the occurrence of merchants in the first and secod transation colums separately
# - Checked the total number of occurrences per column

# %%
# Merchants in the txt_1 or txt_2 columns
df_known_merchs_cp2['txn_desc2'] = df_known_merchs_cp2['txn_desc2'].astype(str)
df_known_merchs_cp2['txn_desc1'] = df_known_merchs_cp2['txn_desc1'].astype(str)
df_known_merchs_cp2['merchant_name'] = df_known_merchs_cp2['merchant_name'].astype(str)
df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] = df_known_merchs_cp2.apply(lambda x: check_names(x.merchant_name, x.txn_desc2), axis=1) # OR txn_desc2
df_known_merchs_cp2.sample(5)
# Out:
#                             transaction_id                        txn_desc1  \
# 323088   Tcc93554334923143a90ddabe5308f8f5  Purchase GOOGLE *Supertreat Gmb
# 1442661  T89af92381bc434faa979f71eef14f3fb            Withdrawal DEBIT CARD
# 459220   T84203b4fa9023ce69ff7046e05679470       Withdrawal Debit TACO BELL
# 518563   Tee759fafb0653ea9823d3463ea93d660                    Card purchase
# 1325140  T0d94e4370a7236309d7122fd65533dba     External Withdrawal T-MOBILE
#
#                                                                       txn_desc2  \
# 323088                                                        855-836-3987 CAUS
# 1442661  TARGET *08 KANSAS CITY MO Date 02/15/23 ***51560 5411 %% Card 15 #5582
# 459220                                                           * ORLANDO FLUS
# 518563           SQ *NUTRITION WITH ATT 5965 (2022-12-21) Nederland TX TSDAFEQH
# 1325140                                                  800-937-8997 - PCS SVC
#
#                 payment_agent merchant_name  CHECK_MERCH_TRA_cp
# 323088                 GOOGLE        GOOGLE               False
# 1442661  Unknow Payment Agent        TARGET                True
# 459220   Unknow Payment Agent     TACO BELL               False
# 518563                 SQUARE          AT&T               False
# 1325140  Unknow Payment Agent      T-MOBILE               False

# %%
print('Total of transactions with known merchants:\n',len(df_known_merchs_cp2))
# Out:
# Total of transactions with known merchants:
#  10000

# %%
print('Merchant name occurrence in txn_desc1 column:\n',(df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] == True).sum())
# Out:
# Merchant name occurrence in txn_desc1 column:
#  6971

# %%
df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] = df_known_merchs_cp2.apply(lambda x: check_names(x.merchant_name, x.txn_desc2), axis=1)
print('Merchant name occurrence in txn_desc2 column:\n',(df_known_merchs_cp2['CHECK_MERCH_TRA_cp'] == True).sum())
# Out:
# Merchant name occurrence in txn_desc2 column:
#  6971

# %% [markdown]
# - Checked occurrence of merchants in concatenated transaction column
# - Created CHECK_MERCH_TRA to inspect occurrences
# - Checked total number of occurences in merchant details coolumn

# %%
# Checking if merchant names are mentioned in the transaction description
df_known_merchs['CHECK_MERCH_TRA'] = df_known_merchs.apply(lambda x: check_names(x.AFS_MECHANT_NAMES, x.TRANSACTION_DETAILS), axis=1)
df_known_merchs.head(10)
# Out:
#                             transaction_id  \
# 793570   T59f1843392b63c0d810fa14b4db6d7b2
# 102727   Te7284534069a3632a6e511010d7f65b7
# 1474089  T246c3f9fe70939e3bdb2e4569945c45d
# 164115   Tb9b7ad9ee99f3fe0b3ac797c09c902b7
# 1139311  T68ed35bd507f31a89822f5a88dcb3db9
# 261629   Tfd49e7d580cd390192081d334e1054c9
# 552301   T31429217c11533de918a0138e9b77607
# 155103   Ta95e3d73984035949a0081104e6ab745
# 661887   Teb0480b8ca54364b8b4e79908e43e9f8
# 1381566  Te7587b4b09973df9b6534a766397b8fa
#
#                                                                              TRANSACTION_DETAILS  \
# 793570                Point Of Sale Withdrawal %%%%% AMAZON.COM*JB5A82DG3 AMAZON.COM SEATTLE WAU
# 102727                                       Withdrawal POS %%%%% DOLLAR-GENERAL # DG *70 PENN L
# 1474089                 Withdrawal Debit Card %%%%% Withdrawal WALMART.COM *6546 800-966-6546 AR
# 164115   Point Of Sale Withdrawal Pinned %%%%% THE HOME DEPOT 139 COMMERCIAL ROADLEOMINSTER MAUS
# 1139311               DBT CRD 1456 05/10/22 *9 FOOD LION #0871 SHEPHERDSTOWN WV C#8557 %%%%% nan
# 261629                                                              Withdrawal NETFLIX %%%%% nan
# 552301                                Withdrawal POS %%%%% CARTER S #1307 100 ROBINSON CENTER DR
# 155103                                       POS Transaction %%%%% COSTCO WHSE #1079 TUCSON AZUS
# 661887                                                       LUMENCENTURYLINK SPEEDPAY %%%%% nan
# 1381566                     DBT CRD 2054 11/04/22 *88 ATT* BILL PAYMENT 800-331-0500TX %%%%% nan
#
#            AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 793570   Unknow Payment Agent        AMAZON.COM             True
# 102727   Unknow Payment Agent    DOLLAR GENERAL             True
# 1474089  Unknow Payment Agent           WALMART             True
# 164115   Unknow Payment Agent        HOME DEPOT             True
# 1139311  Unknow Payment Agent         FOOD LION             True
# 261629   Unknow Payment Agent           NETFLIX             True
# 552301   Unknow Payment Agent           CARTIER             True
# 155103   Unknow Payment Agent            COSTCO             True
# 661887   Unknow Payment Agent       CENTURYLINK             True
# 1381566  Unknow Payment Agent              AT&T            False

# %%
# Merchant name in the transaction description
print('Merchant name in the transaction description:\n',(df_known_merchs['CHECK_MERCH_TRA'] == True).sum() )
# Out:
# Merchant name in the transaction description:
#  9854

# %% [markdown]
# - Created a copy to encode CHECK_MERCH_TRA results
# - Created a chart to compare the results
# - Created a word cloud of AFS_MECHANT_NAMES to get most frequen merchants
# - Checked how many times merchants are mentioned in transaction details
# - Checked how many times merchants are not in transaction details
# - Created word cloud for merchants not in transaction details

# %%
df_known_merchs_cp = df_known_merchs[['transaction_id','TRANSACTION_DETAILS','AFS_PAYMENT_AGENTS','AFS_MECHANT_NAMES','CHECK_MERCH_TRA']].copy(deep=True)
df_known_merchs_cp.head()
# Out:
#                             transaction_id  \
# 793570   T59f1843392b63c0d810fa14b4db6d7b2
# 102727   Te7284534069a3632a6e511010d7f65b7
# 1474089  T246c3f9fe70939e3bdb2e4569945c45d
# 164115   Tb9b7ad9ee99f3fe0b3ac797c09c902b7
# 1139311  T68ed35bd507f31a89822f5a88dcb3db9
#
#                                                                              TRANSACTION_DETAILS  \
# 793570                Point Of Sale Withdrawal %%%%% AMAZON.COM*JB5A82DG3 AMAZON.COM SEATTLE WAU
# 102727                                       Withdrawal POS %%%%% DOLLAR-GENERAL # DG *70 PENN L
# 1474089                 Withdrawal Debit Card %%%%% Withdrawal WALMART.COM *6546 800-966-6546 AR
# 164115   Point Of Sale Withdrawal Pinned %%%%% THE HOME DEPOT 139 COMMERCIAL ROADLEOMINSTER MAUS
# 1139311               DBT CRD 1456 05/10/22 *9 FOOD LION #0871 SHEPHERDSTOWN WV C#8557 %%%%% nan
#
#            AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 793570   Unknow Payment Agent        AMAZON.COM             True
# 102727   Unknow Payment Agent    DOLLAR GENERAL             True
# 1474089  Unknow Payment Agent           WALMART             True
# 164115   Unknow Payment Agent        HOME DEPOT             True
# 1139311  Unknow Payment Agent         FOOD LION             True

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x="CHECK_MERCH_TRA", data=df_known_merchs_cp)
plt.title("Merchant Names in Transaction Details")

total = len(df_known_merchs_cp["CHECK_MERCH_TRA"])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() + 0.1
    y = p.get_y() + p.get_height()/2

ax2 = ax.twinx()
ax2.set_ylim([0, 100])
ax2.set_ylabel('Number of occurrences (%)')

plt.show()

# %%
print('Percentage of merchant names in T details or not (1/0):\n',
      (df_known_merchs_cp.CHECK_MERCH_TRA).value_counts(normalize=True).mul(100).round(1).astype(str) + '%');
# Out:
# Percentage of merchant names in T details or not (1/0):
#  True     98.5%
# False     1.5%
# Name: CHECK_MERCH_TRA, dtype: object

# %%
# Number of merchant names in transaction details
df_check_true = pd.DataFrame()
df_check_true = df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA'] == True]
print('Number of merchant names in transaction details:\n',len(df_check_true))
# Out:
# Number of merchant names in transaction details:
#  9854

# %%
# Word cloud for more frequent merchant names WHEN merchant name is in transaction description

word_cloud(df_check_true.AFS_MECHANT_NAMES)

# %%
print('Total number of occurences per merchant name:\n',
      (df_check_true.AFS_MECHANT_NAMES).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')
# Out:
# Total number of occurences per merchant name:
#  AMAZON.COM                8.6%
# WALMART                   7.0%
# MCDONALD'S                3.4%
# APPLE STORE               2.8%
# TARGET                    2.5%
#                           ...
# UGG                       0.0%
# CAPTAIN D'S               0.0%
# COST PLUS WORLD MARKET    0.0%
# SHERATON                  0.0%
# BOOKS-A-MILLION           0.0%
# Name: AFS_MECHANT_NAMES, Length: 672, dtype: object

# %%
print('Number of merchant names NOT in the transaction description:\n',
      (df_known_merchs['CHECK_MERCH_TRA'] == False).sum())
# Out:
# Number of merchant names NOT in the transaction description:
#  146

# %%
# Number of merchant names not in transaction details
df_check_false = pd.DataFrame()
df_check_false = df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA'] == False]

# %%
# Word cloud for more frequent merchant names WHEN merchant name is NOT in transaction description
word_cloud(df_check_false.AFS_MECHANT_NAMES)

# %%
print('Total number of occurences per merchant name WHEN merchant name is NOT in transation details:\n', 
      (df_check_false.AFS_MECHANT_NAMES).value_counts(normalize=True).mul(100).round(1).astype(str) + '%')
# Out:
# Total number of occurences per merchant name WHEN merchant name is NOT in transation details:
#  AT&T                            40.4%
# AMAZON.COM                       8.9%
# NBC UNIVERSAL                    8.2%
# AMAZONVOD                        5.5%
# MENARDS                          5.5%
# WELLS FARGO                      4.1%
# DUNKIN' DONUTS                   2.7%
# DISNEY PARKS AND EXPERIENCES     2.7%
# FIVE GUYS                        2.1%
# WEIGHT WATCHERS                  2.1%
# VENUS                            1.4%
# METLIFE                          1.4%
# EZPASS PREPAID TOLL              1.4%
# BUFFALO WILD WINGS               1.4%
# STOP & SHOP                      0.7%
# AMERICAN EAGLE                   0.7%
# EBAY                             0.7%
# O'REILLY AUTOMOTIVE              0.7%
# GENERAL MOTORS                   0.7%
# QT GAS                           0.7%
# HY-VEE-FOODS                     0.7%
# BI-LO                            0.7%
# BJ'S WHOLESALE CLUB              0.7%
# YOUTUBE TV                       0.7%
# REGAL CINEMAS                    0.7%
# NINETY NINE RESTAURANTS          0.7%
# DOORDASH                         0.7%
# APPLE STORE                      0.7%
# BANK OF AMERICA                  0.7%
# BUY BUY BABY                     0.7%
# CARTIER                          0.7%
# RED ROBIN RESTAURANTS            0.7%
# Name: AFS_MECHANT_NAMES, dtype: object

# %% [markdown]
# - Merchant names not mentioned in transaction description

# %%
# Merchant names not mentioned in transaction description
df_known_merchs.loc[df_known_merchs['CHECK_MERCH_TRA']==False]
# Out:
#                             transaction_id  \
# 1381566  Te7587b4b09973df9b6534a766397b8fa
# 462467   T816f2e2879003fbd92bbe5872054c966
# 73092    T9e79a78f35e13ba2a402dd445228db8c
# 1270979  Te9b44d9831f73133a807da9573ee3d43
# 1269365  Td27968c7adc93b4c8318c70c3cfe8f18
# ...                                    ...
# 1460352  T87bf43b47654351db30982861bee67ef
# 889109   Td72c8db71dd131218b63a33477ab0805
# 1290908  T75c45ec57ad53327ae0af6b6bd64de76
# 1273362  Tfa7091fce1ee33c3aafe945d5d5c89e8
# 657012   Tacb3564cc7b038b0a9e41e80e8b399e3
#
#                                                                  TRANSACTION_DETAILS  \
# 1381566         DBT CRD 2054 11/04/22 *88 ATT* BILL PAYMENT 800-331-0500TX %%%%% nan
# 462467          Point Of Sale Withdrawal PRIME %%%%% VIDEO*HW16D6TP2 888-802-3080 WA
# 73092                     Withdrawal Debit ATT* BILL %%%%% PAYMENT 800-331-0500 TXUS
# 1270979                    POS Withdrawal Kindle %%%%% Unltd*HE51S2888-802-3080 WAUS
# 1269365                           Purchase ATT* BILL PAYMENT %%%%% 800-331-0500 TXUS
# ...                                                                              ...
# 1460352             DEBIT CARD DEBIT %%%%% auth #* 06-17-2022 DD/BR #* SHREWSBURY PA
# 889109        DEBIT CARD DEBIT %%%%% 05-20-2022 5GUYS 1404 QSR FLORISSANT MO auth #*
# 1290908  DEBIT CARD DEBIT %%%%% 01-25-2023 ATT* BILL PAYMENT 800-331-0500 TX auth #*
# 1273362                                 POS WW INT'L-DIGITAL %%%%% 800-221-2112 NYUS
# 657012                                       External Withdrawal ATT - %%%%% Payment
#
#            AFS_PAYMENT_AGENTS AFS_MECHANT_NAMES  CHECK_MERCH_TRA
# 1381566  Unknow Payment Agent              AT&T            False
# 462467   Unknow Payment Agent         AMAZONVOD            False
# 73092    Unknow Payment Agent              AT&T            False
# 1270979  Unknow Payment Agent        AMAZON.COM            False
# 1269365  Unknow Payment Agent              AT&T            False
# ...                       ...               ...              ...
# 1460352  Unknow Payment Agent    DUNKIN' DONUTS            False
# 889109   Unknow Payment Agent         FIVE GUYS            False
# 1290908  Unknow Payment Agent              AT&T            False
# 1273362  Unknow Payment Agent   WEIGHT WATCHERS            False
# 657012   Unknow Payment Agent              AT&T            False
#
# [146 rows x 5 columns]
